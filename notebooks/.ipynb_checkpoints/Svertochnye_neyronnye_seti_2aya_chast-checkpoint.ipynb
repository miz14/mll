# %%
import tensorflow as tf
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

# %%
train_ds, test_ds = tf.keras.utils.image_dataset_from_directory(
    "../data/101_ObjectCategories",
    validation_split=0.2, 
    subset="both", 
    seed=42,
    image_size=(224,224), 
    batch_size=32, 
)
# Out:
# Found 607 files belonging to 3 classes.
# Using 486 files for training.
# Using 121 files for validation.

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
vgg = tf.keras.applications.VGG19(weights='imagenet', include_top=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels.h5
# 574710816/574710816 [==============================] - 57s 0us/step

# %%
inp = vgg.input
new_classification_layer = tf.keras.layers.Dense(3, activation='softmax')
out = new_classification_layer(vgg.layers[-2].output)
model_new = tf.keras.Model(inp, out)

# %%
for layer in model_new.layers:
    layer.trainable = False
model_new.layers[-1].trainable = True
model_new.layers[-2].trainable = True

# %%
model_new.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history_1 = model_new.fit(train_ds, epochs=5, validation_data=test_ds)
# Out:
# Epoch 1/5
# 16/16 [==============================] - 55s 3s/step - loss: 2.5303 - accuracy: 0.8992 - val_loss: 2.9885 - val_accuracy: 0.9504
# Epoch 2/5
# 16/16 [==============================] - 53s 3s/step - loss: 0.1065 - accuracy: 0.9959 - val_loss: 2.1055 - val_accuracy: 0.9587
# Epoch 3/5
# 16/16 [==============================] - 53s 3s/step - loss: 7.3586e-10 - accuracy: 1.0000 - val_loss: 1.5994 - val_accuracy: 0.9669
# Epoch 4/5
# 16/16 [==============================] - 53s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.5107 - val_accuracy: 0.9669
# Epoch 5/5
# 16/16 [==============================] - 52s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.4919 - val_accuracy: 0.9669

# %%
img = tf.keras.preprocessing.image.load_img(
    "D:/ML/data/101_ObjectCategories/accordion/image_0001.jpg", target_size=(224, 224)
)
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model_new.predict(img_array)
predictions
# Out:
# 1/1 [==============================] - 0s 176ms/step
# array([[0., 1., 0.]], dtype=float32)

# %%
inception = tf.keras.applications.InceptionV3(weights='imagenet', include_top=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels.h5
# 96112376/96112376 [==============================] - 11s 0us/step

# %%
train_ds, test_ds = tf.keras.utils.image_dataset_from_directory(
    "D:/ML/data/101_ObjectCategories",
    validation_split=0.2, 
    subset="both", 
    seed=42,
    image_size=(299,299), 
    batch_size=32, 
)
# Out:
# Found 607 files belonging to 3 classes.
# Using 486 files for training.
# Using 121 files for validation.

# %%
inp = inception.input
new_classification_layer = tf.keras.layers.Dense(3, activation='softmax')
out = new_classification_layer(inception.layers[-2].output)
model_new2 = tf.keras.Model(inp, out)

# %%
for layer in model_new2.layers:
    layer.trainable = False
model_new2.layers[-1].trainable = True
model_new2.layers[-2].trainable = True

# %%
model_new2.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history_2 = model_new2.fit(train_ds, epochs=5, validation_data=test_ds)
# Out:
# Epoch 1/5
# 16/16 [==============================] - 24s 1s/step - loss: 8.2038 - accuracy: 0.6399 - val_loss: 6.1902 - val_accuracy: 0.3471
# Epoch 2/5
# 16/16 [==============================] - 20s 1s/step - loss: 3.5505 - accuracy: 0.6605 - val_loss: 1.8726 - val_accuracy: 0.7603
# Epoch 3/5
# 16/16 [==============================] - 21s 1s/step - loss: 2.2477 - accuracy: 0.7284 - val_loss: 1.7631 - val_accuracy: 0.7769
# Epoch 4/5
# 16/16 [==============================] - 21s 1s/step - loss: 1.9363 - accuracy: 0.7366 - val_loss: 2.8492 - val_accuracy: 0.6116
# Epoch 5/5
# 16/16 [==============================] - 20s 1s/step - loss: 1.1685 - accuracy: 0.7860 - val_loss: 1.5161 - val_accuracy: 0.7851

# %%
img = tf.keras.preprocessing.image.load_img(
    "D:/ML/data/101_ObjectCategories/accordion/image_0001.jpg", target_size=(299, 299)
)
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model_new2.predict(img_array)
predictions
# Out:
# 1/1 [==============================] - 0s 75ms/step
# array([[1.01461217e-01, 8.98538768e-01, 1.07058695e-10]], dtype=float32)

# %%
plt.plot(history_1.history['accuracy'], label='accuracy1')
plt.plot(history_1.history['val_accuracy'], label = 'val_accuracy1')
plt.plot(history_2.history['accuracy'], label='accuracy2')
plt.plot(history_2.history['val_accuracy'], label = 'val_accuracy2')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
